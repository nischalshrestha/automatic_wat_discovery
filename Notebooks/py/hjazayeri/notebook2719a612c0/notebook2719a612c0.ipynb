# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('../input/train.csv', index_col='PassengerId')
test = pd.read_csv('../input/test.csv', index_col='PassengerId')

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
dataset = train.append(test)

# %%
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
sex_map = {'female': 1, 'male': 0}
embark_map = {None: 0, 'S': 1, 'C': 2, 'Q': 3}
title_map = {
    'Col': 0,
    'Jonkheer': 0,
    'Capt': 0,
    'Don': 0,
    'Lady': 0,
    'Countess': 0,
    'Mme': 0,
    'Mr': 1,
    'Sir': 1,
    'Miss': 2,
    'Ms': 2,
    'Mrs': 3,
    'Master': 4,
}

for t in [train, test]:
    t['Age'] = t['Age'].fillna(dataset['Age'].median())
    t['Sex'] = t['Sex'].map(sex_map)
    t['Embarked'] = t['Embarked'].map(embark_map)
    t['title'] = t['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    t['title'] = t['title'].map(title_map).fillna(0)
    t['Fare'] = t['Fare'].fillna(dataset['Fare'].median())

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  Embarked  title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN         1    1.0
# 2                1      0          PC 17599  71.2833   C85         2    3.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN         1    2.0
# 4                1      0            113803  53.1000  C123         1    3.0
# 5                0      0            373450   8.0500   NaN         1    1.0

# %%
s = StandardScaler()
for c in ('Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'title', 'Embarked'):
    train[c] = s.fit_transform(train[c].values.reshape(-1, 1))
    test[c] = s.fit_transform(test[c].values.reshape(-1, 1))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train.head()
# Out:
#              Survived    Pclass  \
# PassengerId
# 1                   0  0.827377
# 2                   1 -1.566107
# 3                   1  0.827377
# 4                   1 -1.566107
# 5                   0  0.827377
#
#                                                           Name  Sex       Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0 -0.565736
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  0.663861
# 3                                       Heikkinen, Miss. Laina    1 -0.258337
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  0.433312
# 5                                     Allen, Mr. William Henry    0  0.433312
#
#                 SibSp     Parch            Ticket      Fare Cabin  Embarked  \
# PassengerId
# 1            0.432793 -0.473674         A/5 21171 -0.502445   NaN -0.562619
# 2            0.432793 -0.473674          PC 17599  0.786845   C85  1.003923
# 3           -0.474545 -0.473674  STON/O2. 3101282 -0.488854   NaN -0.562619
# 4            0.432793 -0.473674            113803  0.420730  C123 -0.562619
# 5           -0.474545 -0.473674            373450 -0.486337   NaN -0.562619
#
#                 title
# PassengerId
# 1           -0.643709
# 2            1.528809
# 3            0.442550
# 4            1.528809
# 5           -0.643709

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# title         0
# dtype: int64
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       327
# Embarked      0
# title         0
# dtype: int64

# %%
X_train = train.drop(['Name', 'Survived', 'Ticket', 'Cabin'], axis=1)
y_train = train['Survived']

X_test = test.drop(['Name', 'Ticket', 'Cabin'], axis=1)

# %%
X_train.head()
# Out:
#                Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  \
# PassengerId
# 1            0.827377    0 -0.565736  0.432793 -0.473674 -0.502445 -0.562619
# 2           -1.566107    1  0.663861  0.432793 -0.473674  0.786845  1.003923
# 3            0.827377    1 -0.258337 -0.474545 -0.473674 -0.488854 -0.562619
# 4           -1.566107    1  0.433312  0.432793 -0.473674  0.420730 -0.562619
# 5            0.827377    0  0.433312 -0.474545 -0.473674 -0.486337 -0.562619
#
#                 title
# PassengerId
# 1           -0.643709
# 2            1.528809
# 3            0.442550
# 4            1.528809
# 5           -0.643709

# %%
X_test.head()
# Out:
#                Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  \
# PassengerId
# 892          0.873482    0  0.371062 -0.499470 -0.400248 -0.497413  2.243165
# 893          0.873482    1  1.358985  0.616992 -0.400248 -0.512278 -0.677841
# 894         -0.315819    0  2.544493 -0.499470 -0.400248 -0.464100  2.243165
# 895          0.873482    0 -0.221692 -0.499470 -0.400248 -0.482475 -0.677841
# 896          0.873482    1 -0.616861  0.616992  0.619896 -0.417492 -0.677841
#
#                 title
# PassengerId
# 892         -0.707748
# 893          1.405385
# 894         -0.707748
# 895         -0.707748
# 896          1.405385

# %%
from sklearn.linear_model import LogisticRegressionCV
m = LogisticRegressionCV()
m.fit(X_train, y_train)
print([s.mean() for s in m.scores_[1]])
y_test = m.predict(X_test)

submission = X_test.copy()
submission['Survived'] = y_test
submission.head()

submission.to_csv('submission.csv', columns=['Survived'])
# Out:
# [0.76228956228956224, 0.76868686868686864, 0.78552188552188551]

# %%
from sklearn.svm import SVC
m = SVC()
m.fit(X_train, y_train)
print(m.score(X_train, y_train))
y_test = m.predict(X_test)

submission = X_test.copy()
submission['Survived'] = y_test
submission.head()

submission.to_csv('submission.csv', columns=['Survived'])
# Out:
# 0.843995510662
